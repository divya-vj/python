# %%
#Arrays
cars = ["Ford", "Volvo", "BMW"]
print(cars)
print(cars[0])
cars[0]='toyata'
print(cars)
print(len(cars))
# Out:
# ['Ford', 'Volvo', 'BMW']
# Ford
# ['toyata', 'Volvo', 'BMW']
# 3

# %%
for x in cars:
    print(x)
# Out:
# toyata
# Volvo
# BMW

# %%
cars.append('honda')

print(cars)
# Out:
# ['toyata', 'Volvo', 'honda', 'honda']

# %%
cars.pop(2)
print(cars)
# Out:
# ['toyata', 'Volvo', 'honda']
